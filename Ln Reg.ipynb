# %% [markdown]
# # Linear Regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
X_R1, y_R1 = make_regression(n_samples = 100, n_features=1,
                            n_informative=1, bias = 150.0,
                            noise = 30, random_state=0)
X_train,X_test,y_train,y_test = train_test_split(X_R1,y_R1,random_state = 0)
linear_reg = LinearRegression().fit(X_train,y_train)

# %%
print('Coefficient:',linear_reg.coef_)
print('Intercept:',linear_reg.intercept_)
print('Train Score:',linear_reg.score(X_train,y_train))
print('Test Score:',linear_reg.score(X_test,y_test))
# Out:
# Coefficient: [45.70870465]
# Intercept: 148.44575345658873
# Train Score: 0.6785950771141656
# Test Score: 0.49159615934930306

# %%
plt.figure(figsize=(8,6))
plt.scatter(X_R1,y_R1,marker='o',s=50,alpha=0.8)
plt.plot(X_R1,linear_reg.coef_*X_R1+linear_reg.intercept_,'r-')
plt.show()
